# %%
import pandas as pd 

df_2021 = pd.read_csv('../data/raw_data/2021.csv')

# %%
# ...existing code...
pd.set_option('display.max_columns', None)
df_2021.head(20)
# Out:
#     _id  AREA_ID  AREA_ATTR_ID  PARENT_AREA_ID  AREA_SHORT_CODE  \
# 0    87  2502280      26022795             NaN               69
# 1   145  2502222      26022737             NaN               10
# 2   158  2502209      26022724             NaN               21
# 3    15  2502352      26022867             NaN              148
# 4    11  2502356      26022871             NaN              152
# 5   118  2502249      26022764             NaN               35
# 6    47  2502320      26022835             NaN              159
# 7    46  2502321      26022836             NaN              160
# 8    72  2502295      26022810             NaN              116
# 9   110  2502257      26022772             NaN               43
# 10   71  2502296      26022811             NaN              118
# 11  109  2502258      26022773             NaN               44
# 12    8  2502359      26022874             NaN              155
# 13   38  2502329      26022844             NaN              168
# ...
